# %%
import h5py

no_E_path = 'simulation_data_no_E.h5'
with h5py.File(no_E_path, 'r') as f:
    no_E_trajectories_data = f['trajectories']['trajectories'][:]

path = 'simulation_data.h5'
with h5py.File(path, 'r') as f:
    trajectories_data = f['trajectories']['trajectories'][:]

# %%
import src.renderer as rd 

renderer = rd.Renderer()
renderer.render_lines(trajectories_data, color='red')
renderer.plotter.show()
# Out:
# rendered
# Widget(value='<iframe src="http://localhost:53329/index.html?ui=P_0x1977e8a4620_0&reconnect=auto" class="pyvis…
