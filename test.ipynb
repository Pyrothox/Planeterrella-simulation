# %%
from main import main 

diags = main()
# Out:
# Output()
# Ec range (eV): 39.99999999999995 40.00000000000004 median: 39.99999999999999
# Fraction of electrons above N2 B3 threshold (7.35eV): 1.0
# Fraction above N2 C3 threshold (11.03eV): 1.0
# nu_N2_inel stats: 36204991.37910107 36204991.3791012 36204991.379101135
# nu_N2_el stats: 1807949387305.7822 1807949387305.7834 1807949387305.7825
# Loading experiment configuration...
# Experiment configuration loaded successfully.
# Rendering experiment...
# Starting simulation...
# Running simulation with the following settings:
# Geometry: <src.geometry.Planeterrella object at 0x0000021E75380170>
# Gas: <src.gas.Gas object at 0x0000021E731E6240>
# Simulation Settings: {'Nparticles': 500, 'Nsteps': 10000, 'voltage': 40}
# Ec range (eV): 0.0 40.000000000000576 median: 39.99999999999999
# Fraction of electrons above N2 B3 threshold (7.35eV): 0.958
# Fraction above N2 C3 threshold (11.03eV): 0.958
# nu_N2_inel stats: 0.0 36204991.37910197 34684381.741178855
# ...

# %%
import numpy as np
ncollisions = diags.collisionRecorder.ncollisions
collisions = diags.collisionRecorder.collisions[:ncollisions]
inel_number = np.sum([(collisions[i][1] == True) for i in range(ncollisions)])
print(f"Total number of collisions: {inel_number}")
# Out:
# Total number of collisions: 144
