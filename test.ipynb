# %%
import main

diags = main.main()
# Out:
# Loading experiment configuration...
# Experiment configuration loaded successfully.
# Rendering experiment...
# Starting simulation...
# Running simulation with the following settings:
# Geometry: <src.geometry.Planeterrella object at 0x000002706F14F2C0>
# Gas: <src.gas.Gas object at 0x000002706F0E77A0>
# Simulation Settings: {'Nparticles': 50, 'Nsteps': 10000, 'voltage': 1000}
# Step: 0
# Step: 100
# Step: 200
# Step: 300
# Step: 400
# Step: 500
# Step: 600
# Step: 700
# Step: 800
# Step: 900
# Step: 1000
# Step: 1100
# Step: 1200
# Step: 1300
# Step: 1400
# Step: 1500
# Step: 1600
# Step: 1700
# Step: 1800
# Step: 1900
# Step: 2000
# Step: 2100
# Step: 2200
# Step: 2300
# Step: 2400
# Step: 2500
# Step: 2600
# Step: 2700
# Step: 2800
# Step: 2900
# Step: 3000
# Step: 3100
# Step: 3200
# Step: 3300
# Step: 3400
# Step: 3500
# Step: 3600
# Step: 3700
# Step: 3800
# Step: 3900
# Step: 4000
# Step: 4100
# Step: 4200
# Step: 4300
# Step: 4400
# Step: 4500
# Step: 4600
# Step: 4700
# Step: 4800
# Step: 4900
# Step: 5000
# Step: 5100
# Step: 5200
# Step: 5300
# Step: 5400
# Step: 5500
# Step: 5600
# Step: 5700
# Step: 5800
# Step: 5900
# Step: 6000
# Step: 6100
# Step: 6200
# Step: 6300
# Step: 6400
# Step: 6500
# Step: 6600
# Step: 6700
# Step: 6800
# Step: 6900
# Step: 7000
# Step: 7100
# Step: 7200
# Step: 7300
# Step: 7400
# Step: 7500
# Step: 7600
# Step: 7700
# Step: 7800
# Step: 7900
# Step: 8000
# Step: 8100
# Step: 8200
# Step: 8300
# Step: 8400
# Step: 8500
# Step: 8600
# Step: 8700
# Step: 8800
# Step: 8900
# Step: 9000
# Step: 9100
# Step: 9200
# Step: 9300
# Step: 9400
# Step: 9500
# Step: 9600
# Step: 9700
# Step: 9800
# Step: 9900

# %%
import numpy as np
print(diags)
np.shape(diags.trajectoryRecorder.get_trajectories())
# Out:
# <src.diagnostics.Diagnostics object at 0x000002706F0C29C0>
# (100, 50, 3)

# %%
from src.renderer import render_empty, render_lines
render_lines(diags)
# Out:
# Widget(value='<iframe src="http://localhost:55419/index.html?ui=P_0x27050ef4ec0_0&reconnect=auto" class="pyvis…

# %%
import tomllib
import numpy as np
with open("config.toml", "rb") as f:
    data = tomllib.load(f)

print(data)

gas_params = data["Gas"]
species = gas_params["species"]
names = np.array([specie["name"] for specie in species])
fractions = np.array([specie["fraction"] for specie in species])
print(fractions)


import src.config
experiment = src.config.load_experiment("config.toml")
# Out:
# {'mode': 3, 'collisions': True, 'Simulation': {'Nparticules': 50, 'Nsteps': 10000, 'voltage': 1000}, 'Gas': {'pressure': 2.5, 'temperature': 300, 'species': [{'name': 'N2', 'fraction': 0.8}, {'name': 'O2', 'fraction': 0.2}]}, 'SmallSphere': {'R': 0.05, 'position': [0, 0.12, 0.2], 'direction': [0, 0, 1]}, 'LargeSphere': {'R': 0.1, 'position': [0, -0.1, 0.2], 'direction': [0, 0.34202014332, 0.93969262078]}, 'Needle': {'position': [0, 0, 0], 'lc': 0.2, 'lb': 0.2, 'r': 0.005, 'direction': [0, 0, 1]}, 'Dome': {'D': 0.5, 'height': 1.0}}
# [0.8 0.2]

# %%
print(experiment.gas.fractions)
print(experiment.gas.names)
names =experiment.gas.names
frac = experiment.gas.fractions

print(frac[names.index("N2")])
# Out:
# [0.8, 0.2]
# ['N2', 'O2']
# 0.8

# %%
import pyvista as pv

sphere1 = pv.Sphere(radius=data["SmallSphere"]["R"], center=data["SmallSphere"]["X"])
sphere2 = pv.Sphere(radius=data["LargeSphere"]["R"], center=data["LargeSphere"]["X"])

plotter = pv.Plotter()
plotter.set_background("black")

plotter.add_mesh(sphere1, color="silver")
plotter.add_mesh(sphere2, color="silver")
plotter.show()
