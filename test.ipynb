# %%
import tomllib
import numpy as np
with open("config.toml", "rb") as f:
    data = tomllib.load(f)

print(data)

gas_params = data["Gas"]
species = gas_params["species"]
names = np.array([specie["name"] for specie in species])
fractions = np.array([specie["fraction"] for specie in species])
print(fractions)


import src.config
experiment = src.config.load_experiment("config.toml")
# Out:
# {'mode': 3, 'collisions': True, 'Simulation': {'Nparticles': 500, 'Nsteps': 10000, 'voltage': 1000}, 'Gas': {'pressure': 25, 'temperature': 300, 'species': [{'name': 'N2', 'fraction': 0.8}, {'name': 'O2', 'fraction': 0.2}]}, 'SmallSphere': {'R': 0.05, 'position': [0, 0.12, 0.2], 'direction': [0, 0, 1]}, 'LargeSphere': {'R': 0.1, 'position': [0, -0.1, 0.2], 'direction': [0, 0.34202014332, 0.93969262078]}, 'Needle': {'position': [0, 0, 0], 'lc': 0.2, 'lb': 0.2, 'r': 0.005, 'direction': [0, 0, 1]}, 'Dome': {'D': 0.5, 'height': 1.0}}
# [0.8 0.2]

# %%
import src.renderer as rd

renderer = rd.Renderer(experiment)
renderer.render_empty()
renderer.PlotB2()
# Out:
# Widget(value='<iframe src="http://localhost:59196/index.html?ui=P_0x2517f08e7b0_0&reconnect=auto" class="pyvis…
# A view with name (P_0x2517f08e7b0_0) is already registered
#  => returning previous one
# Widget(value='<iframe src="http://localhost:59196/index.html?ui=P_0x2517f08e7b0_0&reconnect=auto" class="pyvis…

# %%
print(experiment.gas.fractions)
print(experiment.gas.names)
names =experiment.gas.names
frac = experiment.gas.fractions

print(frac[names.index("N2")])

print(experiment.planeterrella.cathode.position)
# Out:
# [0.8, 0.2]
# ['N2', 'O2']
# 0.8
# [ 0.  -0.1  0.2]

# %%
import pyvista as pv

sphere1 = pv.Sphere(radius=data["SmallSphere"]["R"], center=data["SmallSphere"]["X"])
sphere2 = pv.Sphere(radius=data["LargeSphere"]["R"], center=data["LargeSphere"]["X"])

plotter = pv.Plotter()
plotter.set_background("black")

plotter.add_mesh(sphere1, color="silver")
plotter.add_mesh(sphere2, color="silver")
plotter.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pyvista as pv
#       2
# ----> 3 sphere1 = pv.Sphere(radius=data["SmallSphere"]["R"], center=data["SmallSphere"]["X"])
#       4 sphere2 = pv.Sphere(radius=data["LargeSphere"]["R"], center=data["LargeSphere"]["X"])
#       5
#       6 plotter = pv.Plotter()
#
# KeyError: 'X'
