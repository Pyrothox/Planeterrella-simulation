# %%
import h5py

no_E_path = 'simulation_data_no_E.h5'
with h5py.File(no_E_path, 'r') as f:
    no_E_trajectories_data = f['trajectories']['trajectories'][:]

E_path = 'simulation_data_E.h5'
with h5py.File(E_path, 'r') as f:
    E_trajectories_data = f['trajectories']['trajectories'][:]

# %%
import src.renderer as rd 

renderer = rd.Renderer()
renderer.render_lines(E_trajectories_data, color='red')
renderer.render_lines(no_E_trajectories_data, color='blue')
renderer.plotter.show()
# Out:
# rendered
# rendered
# Widget(value='<iframe src="http://localhost:60478/index.html?ui=P_0x19720f52ff0_0&reconnect=auto" class="pyvis…
